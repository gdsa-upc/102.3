# %%
import os

def evaluate_ranking(indir,gtt, gtv):
    f=open(gtt,'r') #obrim el fitxer ground truth del train i llegim l'interior
    lines=f.read().split()
    f.close()
    dic_gtt={} #crea un diccionari amb la ground truth de train
    par=0
    for line in lines:
        if par==0:
            key=line
            par=1
        else:
            par=0
            dic_gtt[key]=line        
    f=open(gtv,'r') #fem el mateix amb els del tes o validació
    lines=f.read().split()
    f.close()
    dic_gtv={} #crea un diccionari amb la ground truth de validació o test
    par=0
    for line in lines:
        if par==0:
            key=line
            par=1
        else:
            par=0
            dic_gtv[key]=line
       
    ranks = os.listdir(indir)  #llegeixo tots els noms dels fitxers del directori d'entrada i els guarda a ranks
    sumap=0 #suma dels average precisions
    contr=0
    for r in ranks:
        #llegeix els resultats de cada rank
        R=r.rstrip('.txt')
        if R!='Thumb':
            contr=contr+1#contador de ranks
            c=dic_gtv[R]
            f=open(indir+'/'+r)
            lines=f.read().split()
            f.close()
            cont=0 #comptador de resultats
            ce=0 #comptador de resultats encertats
            sump=0 #suma de precisions
            for l in lines:
                if l!='Thumb':
                    cont=cont+1
                    if dic_gtt[l]==c:
                        ce=ce+1
                        sump=sump+(float(ce)/float(cont))
            ap=float(sump)/float(ce)
            sumap=float(sumap)+float(ap)
            print r 
            print' average precision='
            print ap 
            print'\n'
    print 'mean average precision='
    print float(sumap)/float(contr)
    print'\n'

# %%
evaluate_ranking('C:/Users/Ariadna/Documents/GitHub/102.3/ranks','C:/Users/Ariadna/Desktop/train_annotation.txt','C:/Users/Ariadna/Desktop/val_annotation.txt')
# Out:
# 10746-4356-24457.txt
#  average precision=
# 0.0518820596474
#
#
# 10956-21869-28493.txt
#  average precision=
# 0.065182077921
#
#
# 11072-19559-2960.txt
#  average precision=
# 0.0506056305641
#
#
# 11088-24299-26324.txt
#  average precision=
# 0.356102691979
#
#
# 11485-2695-23379.txt
#  average precision=
# 0.0472406419242
#
#
# 11776-28585-22785.txt
#  average precision=
# 0.0950063111391
#
#
# 11783-18760-3162.txt
#  average precision=
# 0.0539745756088
#
#
# 1186-2911-12546.txt
#  average precision=
# 0.372302172823
#
#
# 11929-2134-25457.txt
#  average precision=
# 0.307337320999
#
#
# 11962-11431-11239.txt
#  average precision=
# 0.105413148988
#
#
# 12201-19278-27341.txt
#  average precision=
# 0.0683294940626
#
#
# 12297-2961-2691.txt
#  average precision=
# 0.353686165944
#
#
# 12678-16441-5334.txt
#  average precision=
# 0.0769736744886
#
#
# 1298-19523-5253.txt
#  average precision=
# 0.0456239078243
#
#
# 13107-1101-13819.txt
#  average precision=
# 0.072677303543
#
#
# 13120-15326-15778.txt
#  average precision=
# 0.0535691048531
#
#
# 13275-23968-19108.txt
#  average precision=
# 0.0921811057605
#
#
# 13459-21027-554.txt
#  average precision=
# 0.0729434294492
#
#
# 13473-29072-755.txt
#  average precision=
# 0.331265453328
#
#
# 13704-1450-20278.txt
#  average precision=
# 0.103129220561
#
#
# 13743-7765-21547.txt
#  average precision=
# 0.0499280454181
#
#
# 13973-11176-25136.txt
#  average precision=
# 0.325270488021
#
#
# 14260-9348-29375.txt
#  average precision=
# 0.0604673314404
#
#
# 14339-12777-27191.txt
#  average precision=
# 0.0659453341269
#
#
# 14391-9931-12343.txt
#  average precision=
# 0.328441109036
#
#
# 1464-19265-17047.txt
#  average precision=
# 0.296730135316
#
#
# 1476-17442-9238.txt
#  average precision=
# 0.38267951436
#
#
# 14761-17858-11236.txt
#  average precision=
# 0.0666433466825
#
#
# 1490-1626-23775.txt
#  average precision=
# 0.303103803516
#
#
# 14994-8932-16473.txt
#  average precision=
# 0.0742851579646
#
#
# 15257-18498-26634.txt
#  average precision=
# 0.0650754228362
#
#
# 15414-11863-4424.txt
#  average precision=
# 0.077301632369
#
#
# 15869-11720-7345.txt
#  average precision=
# 0.0610662396676
#
#
# 16140-11798-13017.txt
#  average precision=
# 0.0841330581661
#
#
# 16140-5388-16487.txt
#  average precision=
# 0.084830066019
#
#
# 16245-30237-9134.txt
#  average precision=
# 0.051934514407
#
#
# 16254-1109-6361.txt
#  average precision=
# 0.402875737815
#
#
# 16353-7696-1485.txt
#  average precision=
# 0.356386227448
#
#
# 16464-19979-4516.txt
#  average precision=
# 0.0515037962703
#
#
# 16709-29993-27078.txt
#  average precision=
# 0.327354770687
#
#
# 16714-19434-30572.txt
#  average precision=
# 0.110546518051
#
#
# 168-2743-15592.txt
#  average precision=
# 0.0678874284086
#
#
# 16883-18174-31544.txt
#  average precision=
# 0.062003826462
#
#
# 17156-3055-5516.txt
#  average precision=
# 0.0627515376523
#
#
# 17558-30430-20346.txt
#  average precision=
# 0.380026575371
#
#
# 17591-1568-10744.txt
#  average precision=
# 0.333088960315
#
#
# 17820-14569-28794.txt
#  average precision=
# 0.0741059126769
#
#
# 17930-31341-9770.txt
#  average precision=
# 0.0696150780046
#
#
# 18173-1702-31939.txt
#  average precision=
# 0.0536655420831
#
#
# 18175-12443-14192.txt
#  average precision=
# 0.272149712508
#
#
# 18234-31524-12070.txt
#  average precision=
# 0.0428320654547
#
#
# 18444-1783-21660.txt
#  average precision=
# 0.30036867174
#
#
# 18462-582-6724.txt
#  average precision=
# 0.115789976565
#
#
# 19042-15119-28382.txt
#  average precision=
# 0.375169180812
#
#
# 19076-3014-32447.txt
#  average precision=
# 0.303567240235
#
#
# 19079-24541-20311.txt
#  average precision=
# 0.0705424745016
#
#
# 19306-4219-7889.txt
#  average precision=
# 0.373126058592
#
#
# 19552-8325-7400.txt
#  average precision=
# 0.0612873181457
#
#
# 19603-29348-8344.txt
#  average precision=
# 0.36023457912
#
#
# 20240-21352-25108.txt
#  average precision=
# 0.31949989683
#
#
# 20258-31158-11663.txt
#  average precision=
# 0.360347033672
#
#
# 20276-16872-9737.txt
#  average precision=
# 0.0560614153578
#
#
# 20498-9587-14790.txt
#  average precision=
# 0.072330054965
#
#
# 20655-22019-1804.txt
#  average precision=
# 0.0610302598566
#
#
# 20870-25895-23621.txt
#  average precision=
# 0.312211984061
#
#
# 21330-23648-13493.txt
#  average precision=
# 0.0514735320278
#
#
# 21367-19754-8958.txt
#  average precision=
# 0.0704340447676
#
#
# 21719-15252-18331.txt
#  average precision=
# 0.0494991051436
#
#
# 21732-8850-32604.txt
#  average precision=
# 0.0676696233127
#
#
# 22053-9694-8921.txt
#  average precision=
# 0.34424757312
#
#
# 2235-4849-1445.txt
#  average precision=
# 0.337269711724
#
#
# 224-5466-9020.txt
#  average precision=
# 0.32542639136
#
#
# 22468-29779-12156.txt
#  average precision=
# 0.332710789181
#
#
# 22487-31045-22664.txt
#  average precision=
# 0.305123873206
#
#
# 22489-25271-16290.txt
#  average precision=
# 0.0538703388364
#
#
# 22792-1341-14476.txt
#  average precision=
# 0.0403405051115
#
#
# 22888-20111-25088.txt
#  average precision=
# 0.0556955713448
#
#
# 23046-15667-22189.txt
#  average precision=
# 0.331072889067
#
#
# 23487-16926-9103.txt
#  average precision=
# 0.0690212936595
#
#
# 23541-10032-4923.txt
#  average precision=
# 0.0395238994232
#
#
# 24033-21087-88.txt
#  average precision=
# 0.332262096483
#
#
# 24539-8995-27657.txt
#  average precision=
# 0.0490842535922
#
#
# 24711-1906-29625.txt
#  average precision=
# 0.330818146771
#
#
# 24729-32641-24381.txt
#  average precision=
# 0.0617667403535
#
#
# 24788-27555-23985.txt
#  average precision=
# 0.375038491452
#
#
# 24903-17381-29709.txt
#  average precision=
# 0.105614980789
#
#
# 25192-13600-18321.txt
#  average precision=
# 0.0504636924579
#
#
# 25227-26779-1876.txt
#  average precision=
# 0.343659221624
#
#
# 25390-11369-432.txt
#  average precision=
# 0.131425144064
#
#
# 25495-16266-28201.txt
#  average precision=
# 0.350289068048
#
#
# 25713-13411-21436.txt
#  average precision=
# 0.0401856142804
#
#
# 25739-1999-28698.txt
#  average precision=
# 0.0708812868467
#
#
# 25878-2951-10227.txt
#  average precision=
# 0.355276770768
#
#
# 25930-15672-8602.txt
#  average precision=
# 0.064283984776
#
#
# 2606-12176-27548.txt
#  average precision=
# 0.0565922853792
#
#
# 26096-12781-1864.txt
#  average precision=
# 0.272182988674
#
#
# 26147-18104-14307.txt
#  average precision=
# 0.0562640323836
#
#
# 2623-25984-30912.txt
#  average precision=
# 0.0732916323461
#
#
# 26332-12271-12246.txt
#  average precision=
# 0.325915566834
#
#
# 26619-28637-16723.txt
#  average precision=
# 0.0931969409113
#
#
# 26719-14911-13501.txt
#  average precision=
# 0.0798402505662
#
#
# 27118-21088-19991.txt
#  average precision=
# 0.0806944059948
#
#
# 27203-23875-12583.txt
#  average precision=
# 0.323336736367
#
#
# 27265-28600-25451.txt
#  average precision=
# 0.0482989234936
#
#
# 27370-26503-23248.txt
#  average precision=
# 0.0594421730835
#
#
# 27412-20758-10139.txt
#  average precision=
# 0.0655323798943
#
#
# 27513-26279-6872.txt
#  average precision=
# 0.0768997568348
#
#
# 27525-19898-2032.txt
#  average precision=
# 0.0935301792221
#
#
# 27557-6112-9045.txt
#  average precision=
# 0.391735242571
#
#
# 27608-1911-31456.txt
#  average precision=
# 0.347365588283
#
#
# 27897-23723-8801.txt
#  average precision=
# 0.0510500515527
#
#
# 2807-7096-24202.txt
#  average precision=
# 0.0918366547663
#
#
# 28266-16266-17165.txt
#  average precision=
# 0.0840238911071
#
#
# 28434-29125-25129.txt
#  average precision=
# 0.0700790533317
#
#
# 28661-18003-19405.txt
#  average precision=
# 0.12676675223
#
#
# 28701-20049-5257.txt
#  average precision=
# 0.0609740757667
#
#
# 2877-5281-226.txt
#  average precision=
# 0.0492403385986
#
#
# 28793-6199-11175.txt
#  average precision=
# 0.0944068137237
#
#
# 28842-3880-26033.txt
#  average precision=
# 0.047916514293
#
#
# 28843-24262-2066.txt
#  average precision=
# 0.381986066017
#
#
# 28867-11331-19340.txt
#  average precision=
# 0.30583429955
#
#
# 29105-31712-10753.txt
#  average precision=
# 0.0513977724807
#
#
# 29261-23182-7085.txt
#  average precision=
# 0.0589135002389
#
#
# 29411-26276-24427.txt
#  average precision=
# 0.317067464947
#
#
# 29429-11804-13780.txt
#  average precision=
# 0.115995877635
#
#
# 29785-741-12522.txt
#  average precision=
# 0.307514500133
#
#
# 29911-27486-31219.txt
#  average precision=
# 0.0874495336618
#
#
# 30218-8128-25468.txt
#  average precision=
# 0.0803106965128
#
#
# 30260-8112-5396.txt
#  average precision=
# 0.069051879602
#
#
# 30272-2928-31128.txt
#  average precision=
# 0.302168651908
#
#
# 30384-24302-23862.txt
#  average precision=
# 0.319736701725
#
#
# 30409-23466-8735.txt
#  average precision=
# 0.0531364280166
#
#
# 3061-16710-19252.txt
#  average precision=
# 0.0727481095817
#
#
# 30630-5639-13175.txt
#  average precision=
# 0.0767838571841
#
#
# 31142-23920-20771.txt
#  average precision=
# 0.140369278981
#
#
# 31158-27077-23202.txt
#  average precision=
# 0.0780880893968
#
#
# 31165-13605-23465.txt
#  average precision=
# 0.08253390058
#
#
# 31309-19023-8924.txt
#  average precision=
# 0.115536240277
#
#
# 31439-3018-20900.txt
#  average precision=
# 0.0883172818903
#
#
# 31738-2453-1793.txt
#  average precision=
# 0.301128165107
#
#
# 31923-27875-5932.txt
#  average precision=
# 0.0837041721607
#
#
# 3302-11063-14946.txt
#  average precision=
# 0.0776058246157
#
#
# 3336-28775-26503.txt
#  average precision=
# 0.086054284708
#
#
# 3340-5365-24391.txt
#  average precision=
# 0.0500597950784
#
#
# 3654-4189-15667.txt
#  average precision=
# 0.0875260183256
#
#
# 3680-16272-2487.txt
#  average precision=
# 0.042120676666
#
#
# 3886-4500-23395.txt
#  average precision=
# 0.0845638983943
#
#
# 4085-23631-19519.txt
#  average precision=
# 0.0427767368449
#
#
# 4188-13261-26350.txt
#  average precision=
# 0.0748398213906
#
#
# 4352-29802-58.txt
#  average precision=
# 0.074611683877
#
#
# 4466-21410-10915.txt
#  average precision=
# 0.374553617603
#
#
# 4516-28549-2929.txt
#  average precision=
# 0.111373215497
#
#
# 4626-21534-28661.txt
#  average precision=
# 0.0643481521446
#
#
# 4632-19251-11710.txt
#  average precision=
# 0.0729926269604
#
#
# 5196-26083-31407.txt
#  average precision=
# 0.31574413178
#
#
# 5306-2939-11545.txt
#  average precision=
# 0.088163981336
#
#
# 5367-12636-6143.txt
#  average precision=
# 0.06609066783
#
#
# 5463-5407-9891.txt
#  average precision=
# 0.315715499279
#
#
# 5560-13296-11629.txt
#  average precision=
# 0.351764663212
#
#
# 5774-5348-9669.txt
#  average precision=
# 0.0467268984262
#
#
# 5929-28728-13896.txt
#  average precision=
# 0.339870435515
#
#
# 5977-9240-18389.txt
#  average precision=
# 0.355200925828
#
#
# 6046-9306-17066.txt
#  average precision=
# 0.370259580932
#
#
# 6355-27830-22728.txt
#  average precision=
# 0.0688963136226
#
#
# 6631-1593-26486.txt
#  average precision=
# 0.352277804044
#
#
# 6894-9771-4673.txt
#  average precision=
# 0.0849756500811
#
#
# 7002-26726-26996.txt
#  average precision=
# 0.054891114798
#
#
# 710-26555-29647.txt
#  average precision=
# 0.0657122003523
#
#
# 7366-8116-30743.txt
#  average precision=
# 0.357446082609
#
#
# 7385-12824-32343.txt
#  average precision=
# 0.414346305481
#
#
# 7425-17993-4519.txt
#  average precision=
# 0.0605821652359
#
#
# 7557-22130-12394.txt
#  average precision=
# 0.362554420304
#
#
# 7684-22908-26752.txt
#  average precision=
# 0.0443350527796
#
#
# 7948-25004-22676.txt
#  average precision=
# 0.105570684702
#
#
# 8921-27314-19080.txt
#  average precision=
# 0.0516161566799
#
#
# 9130-27359-869.txt
#  average precision=
# 0.0465615188535
#
#
# 9378-16990-9505.txt
#  average precision=
# 0.062740417282
#
#
# 9459-14212-11225.txt
#  average precision=
# 0.383374009564
#
#
# 9646-29592-32410.txt
#  average precision=
# 0.0972605122899
#
#
# 9968-26718-895.txt
#  average precision=
# 0.047167993947
#
#
# mean average precision=
# 0.16033059107
