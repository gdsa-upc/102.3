# %%
import pickle

# %%
import random

# %%
import numpy as np

# %%
labels = ['catedral','mercat_independencia','mnactec','masia_freixa','castell_cartoixa','societat_general','estacio_nord','dona_treballadora','escola_enginyeria','farmacia_albinyana','teatre_principal','ajuntament','desconegut']

# %%
def classify (dicc, outdir):
    outfile = open(outdir+'/CL.txt','r+')
    val_id = open(dicc, 'rb')
    mydict = pickle.load(val_id)
    ides=mydict.keys()

    for ids in ides:
        lab=labels[np.random.random_integers(0,12)]
        outfile.write(ids + ' ' + lab+ '\n')
        print ids+'\t'+lab+'\n'
    val_id.close()
    outfile.close()

# %%
classify('C:/Users/Ariadna/Documents/GitHub/102.3/Val_diccionari.pickle','C:/Users/Ariadna/Documents/GitHub/102.3')
# Out:
# 21732-8850-32604	farmacia_albinyana
#
# 26619-28637-16723	estacio_nord
#
# 224-5466-9020	masia_freixa
#
# 18175-12443-14192	desconegut
#
# 4085-23631-19519	societat_general
#
# 30409-23466-8735	catedral
#
# 30630-5639-13175	farmacia_albinyana
#
# 31142-23920-20771	teatre_principal
#
# 31165-13605-23465	catedral
#
# 23541-10032-4923	farmacia_albinyana
#
# 21330-23648-13493	catedral
#
# 20498-9587-14790	desconegut
#
# 18234-31524-12070	escola_enginyeria
#
# 22487-31045-22664	desconegut
#
# 2606-12176-27548	farmacia_albinyana
#
# 22888-20111-25088	estacio_nord
#
# 13743-7765-21547	mercat_independencia
#
# 21719-15252-18331	castell_cartoixa
#
# 17930-31341-9770	farmacia_albinyana
#
# 11088-24299-26324	mnactec
#
# 21367-19754-8958	escola_enginyeria
#
# 1476-17442-9238	catedral
#
# 13275-23968-19108	escola_enginyeria
#
# 25227-26779-1876	desconegut
#
# 31158-27077-23202	mercat_independencia
#
# 3336-28775-26503	teatre_principal
#
# 7002-26726-26996	masia_freixa
#
# 5463-5407-9891	societat_general
#
# 29785-741-12522	mercat_independencia
#
# 11962-11431-11239	masia_freixa
#
# 28843-24262-2066	estacio_nord
#
# 3886-4500-23395	catedral
#
# 20655-22019-1804	teatre_principal
#
# 168-2743-15592	desconegut
#
# 17820-14569-28794	desconegut
#
# 24729-32641-24381	farmacia_albinyana
#
# 28793-6199-11175	teatre_principal
#
# 31738-2453-1793	masia_freixa
#
# 11485-2695-23379	escola_enginyeria
#
# 3340-5365-24391	dona_treballadora
#
# 28434-29125-25129	masia_freixa
#
# 23487-16926-9103	ajuntament
#
# 29411-26276-24427	masia_freixa
#
# 16464-19979-4516	catedral
#
# 18462-582-6724	estacio_nord
#
# 27265-28600-25451	mercat_independencia
#
# 4632-19251-11710	catedral
#
# 9968-26718-895	societat_general
#
# 13120-15326-15778	farmacia_albinyana
#
# 11929-2134-25457	catedral
#
# 14339-12777-27191	estacio_nord
#
# 16883-18174-31544	escola_enginyeria
#
# 4188-13261-26350	castell_cartoixa
#
# 9646-29592-32410	mnactec
#
# 26096-12781-1864	dona_treballadora
#
# 10956-21869-28493	teatre_principal
#
# 19306-4219-7889	mnactec
#
# 25390-11369-432	estacio_nord
#
# 3061-16710-19252	teatre_principal
#
# 7557-22130-12394	mercat_independencia
#
# 30260-8112-5396	mnactec
#
# 20276-16872-9737	teatre_principal
#
# 29105-31712-10753	ajuntament
#
# 25930-15672-8602	desconegut
#
# 6355-27830-22728	ajuntament
#
# 28842-3880-26033	desconegut
#
# 30384-24302-23862	mnactec
#
# 11783-18760-3162	dona_treballadora
#
# 25192-13600-18321	catedral
#
# 27525-19898-2032	masia_freixa
#
# 13704-1450-20278	escola_enginyeria
#
# 27557-6112-9045	estacio_nord
#
# 9130-27359-869	escola_enginyeria
#
# 26147-18104-14307	castell_cartoixa
#
# 31439-3018-20900	farmacia_albinyana
#
# 2235-4849-1445	societat_general
#
# 30218-8128-25468	castell_cartoixa
#
# 23046-15667-22189	castell_cartoixa
#
# 19079-24541-20311	farmacia_albinyana
#
# 25713-13411-21436	dona_treballadora
#
# 1186-2911-12546	societat_general
#
# 16140-11798-13017	societat_general
#
# 5977-9240-18389	ajuntament
#
# 27897-23723-8801	societat_general
#
# Thumb	ajuntament
#
# 19552-8325-7400	farmacia_albinyana
#
# 24711-1906-29625	mercat_independencia
#
# 16140-5388-16487	mnactec
#
# 29911-27486-31219	desconegut
#
# 5306-2939-11545	teatre_principal
#
# 28661-18003-19405	masia_freixa
#
# 3680-16272-2487	masia_freixa
#
# 6631-1593-26486	farmacia_albinyana
#
# 2877-5281-226	estacio_nord
#
# 24033-21087-88	mnactec
#
# 1464-19265-17047	mnactec
#
# 26719-14911-13501	mercat_independencia
#
# 14260-9348-29375	mnactec
#
# 13107-1101-13819	masia_freixa
#
# 27203-23875-12583	societat_general
#
# 15414-11863-4424	mnactec
#
# 24788-27555-23985	escola_enginyeria
#
# 22792-1341-14476	estacio_nord
#
# 16353-7696-1485	mnactec
#
# 5560-13296-11629	farmacia_albinyana
#
# 27118-21088-19991	castell_cartoixa
#
# 17591-1568-10744	farmacia_albinyana
#
# 16714-19434-30572	catedral
#
# 5774-5348-9669	ajuntament
#
# 28701-20049-5257	societat_general
#
# 4352-29802-58	dona_treballadora
#
# 10746-4356-24457	estacio_nord
#
# 5367-12636-6143	teatre_principal
#
# 14391-9931-12343	farmacia_albinyana
#
# 14994-8932-16473	masia_freixa
#
# 29261-23182-7085	societat_general
#
# 19042-15119-28382	ajuntament
#
# 1298-19523-5253	teatre_principal
#
# 25878-2951-10227	desconegut
#
# 1490-1626-23775	estacio_nord
#
# 20240-21352-25108	ajuntament
#
# 28266-16266-17165	escola_enginyeria
#
# 27370-26503-23248	castell_cartoixa
#
# 11072-19559-2960	ajuntament
#
# 29429-11804-13780	estacio_nord
#
# 6894-9771-4673	farmacia_albinyana
#
# 20258-31158-11663	mercat_independencia
#
# 13473-29072-755	mnactec
#
# 4516-28549-2929	estacio_nord
#
# 19603-29348-8344	catedral
#
# 5196-26083-31407	desconegut
#
# 27608-1911-31456	catedral
#
# 31923-27875-5932	masia_freixa
#
# 8921-27314-19080	mnactec
#
# 15257-18498-26634	masia_freixa
#
# 24539-8995-27657	masia_freixa
#
# 17156-3055-5516	castell_cartoixa
#
# 16254-1109-6361	castell_cartoixa
#
# 7425-17993-4519	escola_enginyeria
#
# 16245-30237-9134	desconegut
#
# 5929-28728-13896	dona_treballadora
#
# 4626-21534-28661	mercat_independencia
#
# 22489-25271-16290	mnactec
#
# 31309-19023-8924	masia_freixa
#
# 18444-1783-21660	ajuntament
#
# 25495-16266-28201	castell_cartoixa
#
# 18173-1702-31939	escola_enginyeria
#
# 2807-7096-24202	catedral
#
# 17558-30430-20346	mnactec
#
# 7948-25004-22676	desconegut
#
# 9378-16990-9505	desconegut
#
# 30272-2928-31128	escola_enginyeria
#
# 12678-16441-5334	castell_cartoixa
#
# 4466-21410-10915	farmacia_albinyana
#
# 3302-11063-14946	masia_freixa
#
# 7385-12824-32343	masia_freixa
#
# 11776-28585-22785	desconegut
#
# 9459-14212-11225	estacio_nord
#
# 16709-29993-27078	castell_cartoixa
#
# 27513-26279-6872	dona_treballadora
#
# 26332-12271-12246	catedral
#
# 24903-17381-29709	escola_enginyeria
#
# 13973-11176-25136	desconegut
#
# 28867-11331-19340	farmacia_albinyana
#
# 13459-21027-554	masia_freixa
#
# 22468-29779-12156	mercat_independencia
#
# 7366-8116-30743	ajuntament
#
# 12201-19278-27341	societat_general
#
# 6046-9306-17066	dona_treballadora
#
# 27412-20758-10139	catedral
#
# 22053-9694-8921	catedral
#
# 7684-22908-26752	mnactec
#
# 20870-25895-23621	mercat_independencia
#
# 710-26555-29647	masia_freixa
#
# 2623-25984-30912	mercat_independencia
#
# 15869-11720-7345	teatre_principal
#
# 14761-17858-11236	dona_treballadora
#
# 19076-3014-32447	dona_treballadora
#
# 12297-2961-2691	castell_cartoixa
#
# 3654-4189-15667	estacio_nord
#
# 25739-1999-28698	estacio_nord
