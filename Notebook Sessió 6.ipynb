# %% [markdown]
# GDSA 2015: Notebook sessió 6

# %% [markdown]
# En aquest Notebook es mostraràn els resultats obtinguts amb les funcions fetes en la sesió 5 del projecte. Aquestes funcions son: train_classifier, classify i evaluate_classification. El resultat final son les matrius de confussió i els valors de accuracy, precision, recall i f1_score.

# %%
from Parametres import parametres
param = parametres()

# %% [markdown]
# Train_classifier: Aquesta funció genera el diccionari d'entrenament pel nostre classificador. Genera un archiu pickle corresponent al classificador entrenat.

# %%
from train_classifier import train_classifier
train_classifier()

# %% [markdown]
# Classify: En aquesta funció classifiquem les imatges d'evaluació. Li passem al programa el model de classificador entrenat i aquesta funció asigna a cada imatge de validació una classe. El resultat es un fitxer txt amb les id de les imatges i la seva classe corresponent.

# %%
from classify import classify
classify()

# %% [markdown]
# evaluate_classification: En aquesta funció es verifica la cantitat d'encert del nostre classificador. Li entrem el txt generat a classify, verifiquem els resultats i printem els valors de l'accuracy, precision, recall i f1_score. A més, es printen les matrius de confussió corresponents a la evaluació.

# %%
from evaluate_classification import evaluate_classification
evaluate_classification()
# Out:
# Accuracy of system:
# 0.211111111111
#
#
# Precision:
# 0.085641025641
#
#
# Recall:
# 0.0807692307692
#
#
# f1_Score:
# 0.0765775890776

# %%
# %matplotlib inline
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot as plt
import cv2
img = cv2.imread('/'.join([param['arrel_entrada']+'/figure_1.png']),1)
plt.imshow(img)

# %%
# %matplotlib inline
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot as plt
import cv2
img = cv2.imread('/'.join([param['arrel_entrada']+'/figure_2.png']),1)
plt.imshow(img)

# %% [markdown]
# Amb els resultats obtinguts es pot apreciar una milloria amb respecte del classificador random que vam fer. La millora es del ordre de magnitud 10 (de 0.00x a 0.0x).
