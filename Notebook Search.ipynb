# %% [markdown]
# La nostra aplicació per cerca d'imatges ha quedat finalment així, utilitzant 1000 clusters, descriptors ORB i la llibreria scipy.spatial. Aqui tenim un exemple d'un ranking dels que aconseguim amb la nostra funció.

# %%
from Feature_Extraction import Feature_extraction
Feature_extraction()

# %%
from rank import rank
rank()
from Parametres import parametres
params=parametres()
f=open(params['arrel_sortida']+'/rankings/168-2743-15592.txt')
lines=f.read().split()
print 'ranking 168-2743-15592:\n'
for l in lines:
    print l
# Out:
# ranking 168-2743-15592:
#
# 20266-4113-20424
# 211-18679-31286
# 30925-19577-20681
# 10690-18667-24717
# 13165-3173-7669
# 22144-11818-32078
# 7568-9419-21542
# 13982-14440-23434
# 26833-1317-31766
# 51-16676-22265
# 28087-5032-31417
# 21033-11566-16819
# 20480-21005-18776
# 12640-26750-25778
# 23145-21797-3773
# 18349-6056-24676
# 1076-15709-16801
# 18526-1752-24892
# 28314-7959-27714
# 28063-19516-20553
# 23894-17610-345
# 32120-31232-4350
# 5129-4895-16473
# 23378-15741-27721
# 11051-4523-25966
# 13725-29641-11394
# 13212-8671-1126
# 30134-16709-25047
# 17448-13231-5610
# 10984-8222-15245
# 12487-11017-3187
# 19388-25656-4683
# 12012-3785-23764
# 32483-3320-30623
# 32353-29133-15679
# 14573-18930-26440
# 8658-23081-22141
# 26962-32384-18054
# 28153-2397-9738
# 4376-21680-10065
# 4383-9273-22247
# 8107-3097-32556
# 14683-22304-29109
# 9951-25030-4235
# 5555-15557-22970
# 11527-19023-28769
# 28036-31240-25237
# 5568-32337-31553
# 294-22479-6089
# 4406-18633-1754
# 18563-3693-25712
# ...

# %% [markdown]
# La funció evaluate_ranking ens permet evaluar com funciona l'anterior funció buscant el Mean Average Precision(MAP) i les Average Precision.

# %%
from evaluate_ranking import evaluate_ranking
evaluate_ranking()
# Out:
# mean average precision=
# 0.237516228429
# [0.10255388286566643,
#  0.2663755198096713,
#  0.07212699516942812,
#  0.35365084591129603,
#  0.11097386324464312,
#  0.2654971510546152,
#  0.07498858849174954,
#  0.33022684942401054,
#  0.3577908392755053,
#  0.16366346683320224,
#  0.08237596532437219,
#  0.3899203535745584,
#  0.09855645415873102,
#  0.08072492642787225,
#  0.07850278827395632,
#  0.3830852417069531,
#  0.10870630124949451,
#  0.4126859845694809,
#  0.31552670234100955,
#  0.13689025307109715,
#  0.08875987432695136,
#  0.38357564820848816,
#  0.24180393826759886,
#  0.3645120171342891,
#  0.3299548705587451,
#  0.41548658566666175,
#  0.38783337756542663,
#  0.12377694494831905,
#  0.3651433159398668,
#  0.06450590090881016,
#  0.1216617015931693,
#  0.14275826220761634,
#  0.1026940802529386,
#  0.08833355244260162,
#  0.1794255827729786,
#  0.17423168850908155,
#  0.42574797996323305,
#  0.3600566725826088,
#  0.06933479405942418,
#  0.36856297562047285,
# ...
